# %%
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import math
import pandasql as ps
import time
import string
import random
from faker import Faker

from lib.masking_functions import mask, bucketize_age, blur_zip, generalize_diagnosis, add_relative_noise, blur_phone

# %%
def plot_probabilities(dist):
    dist_copy = dist.copy().sort_index()
    # labels = dist.index.to_series().apply(lambda x: '{0}-{1}'.format(*x))
    # labels = dist.index

    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    ax.bar(range(len(dist_copy.values)),dist_copy.values)
    plt.show()

# %% [markdown]
# ## Data Generation

# %%
fake = Faker('de_DE')

from faker.providers import BaseProvider

# create new provider class for diagnosis following the ICD_10_GM medical code
class ICD_10_GM_Provider(BaseProvider):
    def diagnosis(self) -> str:
        letter = random.choice(string.ascii_uppercase.replace("U", "").replace("W", "").replace("X", ""))
        number = np.trunc(np.random.uniform(0.0, 99.9)*10)/(10)
        if number < 10:
            return letter+"0"+str(number)
        else:
            return letter+str(number)
        
fake.add_provider(ICD_10_GM_Provider)

# %%
nRows = 1500

pid = np.arange(1,nRows+1)
age = np.random.normal(60, 20, nRows).astype(int)

# Remove patients with age lower than 18 or higher than 100
invalid = age[np.logical_or(age < 18, age > 100)].size
while invalid > 0:
    age[np.logical_or(age < 18, age > 100)] = np.random.normal(75, 10, invalid).astype(int)
    invalid = age[np.logical_or(age < 18, age > 100)].size

# diagnosis = np.asarray([fake.diagnosis() for i in range(nRows)])
address = np.asarray([fake.street_address() for i in range(nRows)])
zip_code = np.asarray([fake.postcode() for i in range(nRows)])
city = np.asarray([fake.city_name() for i in range(nRows)])
phone_number = np.asarray([fake.unique.phone_number() for i in range(nRows)])

# %%
name = []
gender = []
weight = np.empty(nRows).astype(int)
height = np.empty(nRows).astype(int)

for i in range(nRows):
    rand = np.random.rand()
    if rand < 0.48:
        name.append(fake.unique.name_male())
        gender.append("Male")
        height[i] = int(np.random.normal(180, 7.5))
        weight[i] = int(np.random.normal(80, 10))
    elif rand < 0.98:
        name.append(fake.unique.name_female())
        gender.append("Female")
        height[i] = int(np.random.normal(167, 5))
        weight[i] = int(np.random.normal(60, 7.5))
    else:
        name.append(fake.unique.name_nonbinary())
        gender.append("Non-Binary")
        height[i] = int(np.random.normal(175, 6))
        weight[i] = int(np.random.normal(70, 10))

name = np.asarray(name)
gender = np.asarray(gender)

# %%
diagnosis = []
medication = []

for i in range(nRows):
    rand = np.random.rand()
    if rand < 0.09:
        diagnosis.append("E10")
        medication.append("Insulin")
    elif rand < 0.98:
        diagnosis.append("E11")
        medication.append("Metformin")
    else:
        diagnosis.append("E13")
        medication.append("Insulin")

diagnosis = np.asarray(diagnosis)
medication = np.asarray(medication)
glucose = np.asarray([np.random.randint(60, 450) for i in range(nRows)])
HbA1C = np.asarray([round(random.uniform(4, 12), 2) for i in range(nRows)])
insurance_company = np.asarray([fake.bothify(text='#########') for i in range(nRows)])
insurance_number = np.asarray([fake.bothify(text='?#########', letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ') for i in range(nRows)])

# %% [markdown]
# ### Single Dataset

# %%
name[nRows - 1] = "Henri Allgöwer"
address[nRows - 1] = "Einsteinufer 17"
zip_code[nRows - 1] = 10587
phone_number[nRows - 1] = "01765 123456"
gender[nRows - 1] = "Male"
height[nRows - 1] = 178
weight[nRows - 1] = 68
age[nRows - 1] = 27
insurance_company[nRows - 1] = 101575519
diagnosis[nRows - 1] = "E10"
glucose[nRows - 1] = 453
HbA1C[nRows - 1] = 10.13
medication[nRows - 1] = "Insulin"

data = {'id': pid,
    'name': name, 
    'address': address,
    'zip': zip_code,
    'phone': phone_number,
    'gender': gender, 
    'height': height,
    'weight': weight,
    'age': age,
    'insurance_company': insurance_company,
    'insurance_number': insurance_number,
    'diagnosis': diagnosis,
    'glucose': glucose,
    'HbA1C': HbA1C,
    'medication': medication
}
data
# Out:
# {'id': array([   1,    2,    3, ..., 1498, 1499, 1500]),
#  'name': array(['Ewa Bolnbach B.Eng.', 'Prof. Kamil Killer',
#         'Zdravko Junck-Ritter', ..., 'Grzegorz Striebitz-Steinberg',
#         'Mohamed Speer-Trapp', 'Henri Allgöwer'], dtype='<U41'),
#  'address': array(['Raphael-Mitschke-Ring 54', 'Sybille-Gehringer-Platz 5/1',
#         'Urte-Buchholz-Weg 05', ..., 'Bekir-Hübel-Straße 9',
#         'Häringgasse 463', 'Einsteinufer 17'], dtype='<U34'),
#  'zip': array(['44323', '62668', '02863', ..., '92770', '73153', '10587'],
#        dtype='<U5'),
#  'phone': array(['+49 (0) 8587 907438', '(06798) 192770', '+49(0) 228387024', ...,
#         '+49(0)5554 89976', '+49(0)0221 378223', '+49(0)9475 88536'],
#        dtype='<U19'),
#  'gender': array(['Female', 'Male', 'Male', ..., 'Male', 'Male', 'Male'],
#        dtype='<U10'),
#  'height': array([167, 186, 182, ..., 192, 181, 178]),
#  'weight': array([49, 72, 65, ..., 77, 75, 68]),
#  'age': array([33, 49, 60, ..., 50, 29, 27]),
#  'insurance_company': array(['386481362', '597941858', '621170846', ..., '713021715',
#         '413137099', '101575519'], dtype='<U9'),
#  'insurance_number': array(['X366630042', 'Z382985482', 'B567964048', ..., 'Z005101642',
#         'S101016474', 'R915479186'], dtype='<U10'),
#  'diagnosis': array(['E11', 'E11', 'E11', ..., 'E11', 'E11', 'E10'], dtype='<U3'),
#  'glucose': array([299, 148, 153, ..., 300, 287, 453]),
#  'HbA1C': array([10.17, 10.96,  5.48, ...,  8.34,  9.84, 10.13]),
#  'medication': array(['Metformin', 'Metformin', 'Metformin', ..., 'Metformin',
#         'Metformin', 'Insulin'], dtype='<U9')}

# %%
df_synthetic_data = pd.DataFrame.from_dict(data=data)
#df['phone'] = df['phone'].str.replace(r'[()]',"", regex=True).str.replace(r' ',"", regex=True).str.replace("+49","", regex=False)
df_synthetic_data
# Out:
#         id                           name                      address    zip  \
# 0        1            Ewa Bolnbach B.Eng.     Raphael-Mitschke-Ring 54  44323
# 1        2             Prof. Kamil Killer  Sybille-Gehringer-Platz 5/1  62668
# 2        3           Zdravko Junck-Ritter         Urte-Buchholz-Weg 05  02863
# 3        4        Wieland auch Schlauchin    Annaliese-Ritter-Straße 8  53291
# 4        5      Dipl.-Ing. Cengiz Peukert                  Metzallee 5  62747
# ...    ...                            ...                          ...    ...
# 1495  1496                   Luka Seifert       Volker-Beier-Gasse 337  48065
# 1496  1497  Prof. Rosalinde Mosemann B.A.           Kostolzinallee 025  28890
# 1497  1498   Grzegorz Striebitz-Steinberg         Bekir-Hübel-Straße 9  92770
# 1498  1499            Mohamed Speer-Trapp              Häringgasse 463  73153
# 1499  1500                 Henri Allgöwer              Einsteinufer 17  10587
#
#                     phone  gender  height  weight  age insurance_company  \
# 0     +49 (0) 8587 907438  Female     167      49   33         386481362
# 1          (06798) 192770    Male     186      72   49         597941858
# 2        +49(0) 228387024    Male     182      65   60         621170846
# 3             04614385395    Male     176      78   64         487441118
# 4            05808 937242    Male     195      73   62         873298780
# ...                   ...     ...     ...     ...  ...               ...
# 1495    +49(0)4885 931840  Female     171      64   66         726051066
# 1496       (01314) 003357  Female     169      51   47         500314300
# 1497     +49(0)5554 89976    Male     192      77   50         713021715
# 1498    +49(0)0221 378223    Male     181      75   29         413137099
# 1499     +49(0)9475 88536    Male     178      68   27         101575519
#
#      insurance_number diagnosis  glucose  HbA1C medication
# 0          X366630042       E11      299  10.17  Metformin
# 1          Z382985482       E11      148  10.96  Metformin
# 2          B567964048       E11      153   5.48  Metformin
# 3          K129212042       E11      266   6.34  Metformin
# 4          O671592897       E11      394   4.30  Metformin
# ...               ...       ...      ...    ...        ...
# 1495       I021399442       E11      105   8.07  Metformin
# 1496       L120238073       E11      244   6.93  Metformin
# 1497       Z005101642       E11      300   8.34  Metformin
# 1498       S101016474       E11      287   9.84  Metformin
# 1499       R915479186       E10      453  10.13    Insulin
#
# [1500 rows x 15 columns]

# %%
dir = os.getcwd()
df_synthetic_data.to_csv(dir + "/datasets/single/syntheticData.csv", index=False)

# %% [markdown]
# ### Multiple Dataset

# %%
data_patient = {
    'id' : pid,
    'name': name, 
    'diagnosis': diagnosis,
    'phone': phone_number
}

# %%
df = pd.DataFrame.from_dict(data=data_patient)
#df['phone'] = df['phone'].str.replace(r'[()]',"", regex=True).str.replace(r' ',"", regex=True).str.replace("+49","", regex=False)
df
# Out:
#     id                               name diagnosis                phone
# 0    1            Dr. Magrit Bonbach MBA.     P89.1          00419757814
# 1    2               Hanspeter Beyer B.A.     Z35.9          07300014205
# 2    3              Anatolij Roskoth B.A.     L85.7  +49 (0) 3924 478029
# 3    4       Dipl.-Ing. Teresa Karz B.Sc.     V54.1         02894 343064
# 4    5                     Björn Misicher     N73.9        (01843) 61458
# 5    6               Herrmann Tröst B.Sc.     G38.8     +49(0)4200 21613
# 6    7                 Henner Putz B.Eng.     R09.8  +49 (0) 0058 889198
# 7    8                Traude Hövel-Aumann     K70.7         04948 083163
# 8    9                   Gertraud Langern     V80.4     +49(0)9389 06593
# 9   10   Univ.Prof. Liselotte Hecker B.A.     V45.4     +49(0) 441083097
# 10  11                          Gert Mude     L71.5     +49(0) 355575729
# 11  12            Ing. Hülya Rogge B.Eng.     P95.3           0435193870
# 12  13                        Lotte Zirme     C24.2        (03614) 08736
# 13  14                       Zoran Söding     J94.1     +49(0)1202 79381
# 14  15                    Henri Holzapfel     L21.3     +49(0)0588487496
# 15  16       Univ.Prof. Kemal Eberth MBA.     K93.2          06507820705
# 16  17                    Berthold Eberth     Z13.1          00578788766
# 17  18                  Elly Blümel-Ebert     G57.5          01455204647
# 18  19         Prof. Olivia Wilmsen B.Sc.     T50.5          00422078425
# 19  20     Dipl.-Ing. Ingetraud Hertrampf     J83.6       (09684) 325569
# 20  21                        Paula Wilms     N96.0    +49(0)6415 486272
# 21  22                    Laszlo Eckbauer     O15.3       (00726) 458605
# 22  23                Canan Fischer B.Sc.     Q59.3        (07984) 94726
# 23  24                Marco Hecker B.Eng.     A96.0         03561 010567
# 24  25                    Gerwin Lachmann     B50.6    +49(0)4796 488018
# 25  26  Dipl.-Ing. Stefano Ullmann B.Eng.     K99.6     +49(0)8932504631
# 26  27                     Birgit Seifert     M04.4        (06125) 73497
# 27  28               Miguel Bonbach-Preiß     J17.8           0676271946
# 28  29                 Fatih Döring B.Sc.     V49.2          00137832026
# 29  30                 Filippo Löwer-Seip     I59.7          06129 39944
# 30  31                         Alf Adolph     O15.5         03761 689362
# 31  32                   Siegmund Matthäi     T92.4  +49 (0) 3769 906482
# 32  33                  Dietlind Losekann     F80.8  +49 (0) 9252 030920
# 33  34                Maria-Luise Hartung     M40.1        (00269) 53590
# 34  35           Frau Martha Fritsch B.A.     T79.3    +49(0)8564 568829
# 35  36                         Nuri Krein     G07.4          05800 11855
# 36  37                 August Hethur B.A.     G37.9     +49(0) 560703592
# 37  38                     Carsten Weller     P78.5         08164 942883
# 38  39                     Jose Kostolzin     Q66.1          03159977250
# 39  40                   Dr. Simona Beyer     O06.7       (05594) 834705
# 40  41                      Anneke Jopich     T51.1     +49(0)1950 20788
# 41  42                      Lore Oderwald     S95.0           0222872752
# 42  43                  Ingmar Dussen van     F87.0           0042502486
# 43  44                     Alwin Rörricht     L19.0           0507431548
# 44  45                       Cilli Renner     F31.3           0591047077
# 45  46   Prof. Philipp Austermühle B.Eng.     Y16.5    +49(0)6683 751086
# 46  47                     Georg Gröttner     N35.4         03877 783996
# 47  48                  Karolina Herrmann     J19.1     +49(0)4334233177
# 48  49                  Andrei Dussen van     Q53.9          07754 88495
# 49  50                Ing. Hasso Herrmann     S54.5  +49 (0) 4386 458230

# %%
df.to_csv(dir + "/datasets/multiple/patient.csv", index=False)

# %%
data_physical = {
    'id': pid,
    'gender': gender,
    'age': age,
    'height': height,
    'weight': weight,
}

# %%
df = pd.DataFrame(data=data_physical)
df
# Out:
#     id  gender  age  height  weight
# 0    1  Female   47     165      53
# 1    2    Male   88     180      84
# 2    3    Male   32     180      91
# 3    4  Female   62     162      57
# 4    5    Male   78     180      79
# 5    6    Male   65     183      70
# 6    7    Male   53     180      83
# 7    8  Female   26     168      54
# 8    9  Female   58     162      63
# 9   10  Female   43     167      68
# 10  11    Male   79     176      78
# 11  12  Female   47     160      66
# 12  13  Female   29     171      64
# 13  14    Male   36     170      75
# 14  15  Female   67     172      54
# 15  16    Male   59     191      82
# 16  17    Male   59     189      94
# 17  18  Female   79     169      60
# 18  19  Female   78     163      72
# 19  20  Female   93     168      62
# 20  21  Female   32     167      60
# 21  22    Male   67     187      62
# 22  23  Female   46     165      62
# 23  24    Male   43     168     103
# 24  25    Male   72     172      71
# 25  26    Male   71     186      74
# 26  27  Female   45     171      55
# 27  28    Male   63     185     105
# 28  29    Male   35     174      78
# 29  30    Male   60     181      75
# 30  31    Male   81     190     100
# 31  32    Male   50     180      70
# 32  33  Female   68     170      65
# 33  34  Female   54     167      55
# 34  35  Female   50     170      44
# 35  36    Male   75     189      93
# 36  37    Male   48     189      87
# 37  38    Male   97     165      83
# 38  39    Male   78     186      85
# 39  40  Female   19     165      57
# 40  41  Female   34     170      72
# 41  42  Female   78     170      55
# 42  43    Male   21     171      66
# 43  44    Male   19     186      96
# 44  45  Female   42     166      60
# 45  46    Male   80     176      81
# 46  47    Male   51     180      87
# 47  48  Female   59     161      49
# 48  49    Male   67     176      98
# 49  50    Male   65     179      72

# %%
df.to_csv(dir + "/datasets/multiple/physical.csv")

# %%
data_address = {
    'id': pid,
    'address': address,
    'zip': zip_code,
    'city' : city
}

# %%
df = pd.DataFrame(data=data_address)
df
# Out:
#     id                       address    zip                 city
# 0    1            Olaf-Zobel-Allee 9  24455            Eichstätt
# 1    2               Schomberplatz 7  16661     Osterode am Harz
# 2    3                  Römerplatz 1  23765                 Burg
# 3    4                 Stiffelstr. 9  60825             Rottweil
# 4    5             Paffrathallee 9/5  78781            Pritzwalk
# 5    6                 Mendegasse 84  53313          Hoyerswerda
# 6    7           Neuschäferstraße 20  16128          Mallersdorf
# 7    8         Jolanda-Wilms-Allee 9  44109                Guben
# 8    9                Schülerallee 0  47725       Neubrandenburg
# 9   10        Gerta-Krause-Gasse 843  26285             Pasewalk
# 10  11           Dussen vanallee 5/4  84413  Königs Wusterhausen
# 11  12             Wilmsenstraße 9/1  99364              Rastatt
# 12  13                  Netteallee 1  21885            Wanzleben
# 13  14  Ernestine-Förster-Straße 6/4  61019  Königs Wusterhausen
# 14  15                Wulffallee 192  50037             Bruchsal
# 15  16                Geißlerallee 5  39327            Badibling
# 16  17     Edelgard-Wähner-Straße 82  38001             Arnstadt
# 17  18        Veronica-Etzler-Weg 99  39626             Sömmerda
# 18  19       Christin-Köster-Gasse 1  53465                Peine
# 19  20                Wendegasse 027  95348               Bremen
# 20  21     Helfried-Aumann-Allee 9/9  57178            Säckingen
# 21  22             Säuberlichweg 608  13615              Freital
# 22  23   Hanne-Lore-Flantz-Platz 916  49513                Guben
# 23  24      Sofie-Birnbaum-Straße 08  62506               Siegen
# 24  25                 Walterallee 1  68521           Miltenberg
# 25  26         Anka-Drewes-Allee 916  01897              Einbeck
# 26  27                 Gunpfring 0/6  39478         Haldensleben
# 27  28    Ellinor-Cichorius-Platz 81  25116        Fallingbostel
# 28  29                Preißallee 5/5  66383            Steinfurt
# 29  30   Liselotte-Kitzmann-Gasse 65  81076      Marktheidenfeld
# 30  31               Rosenowallee 94  03280            Steinfurt
# 31  32       Magrit-Junck-Straße 275  83084            Mittweida
# 32  33                 Roggestr. 822  42513        Bischofswerda
# 33  34                   Kochweg 0/5  70517               Weimar
# 34  35       Oxana-Hermann-Allee 769  22558               Bützow
# 35  36     Willibald-Mälzer-Ring 7/0  23293                Guben
# 36  37                 Wilmsstr. 2/9  06187                Eutin
# 37  38             Gutknechtgasse 04  97154           Miltenberg
# 38  39             Hentschelplatz 84  01856           Sankt Goar
# 39  40            Scheuermannplatz 5  84565           Ravensburg
# 40  41               Hertrampfring 7  91153       Wolfratshausen
# 41  42            Lili-Stoll-Ring 20  14542                Guben
# 42  43       Susann-Hermann-Straße 4  71417              Neu-Ulm
# 43  44          Cemil-Täsche-Gasse 3  69164          Lüdenscheid
# 44  45      Andrea-Margraf-Gasse 1/2  96801   Sulzbach-Rosenberg
# 45  46                Binnerring 906  81922       Kaiserslautern
# 46  47       Laila-Scholz-Straße 9/4  01468        Tirschenreuth
# 47  48               Kranzstraße 475  23497   Hansestadttralsund
# 48  49       Manuela-Bloch-Platz 3/5  03000         Rockenhausen
# 49  50               Hübelstraße 898  78621               Erfurt

# %%
np.unique(address).size
# Out:
# 50

# %%
df.to_csv(dir + "/datasets/multiple/contact.csv")

# %% [markdown]
# ## Generate Masked Tables

# %%
b_size = 5
nFields = 2
level = 1
relNoise = 0.05
nFields_phone = 3

masked_low = mask(df_synthetic_data, bucketize_age, 'age', b_size)
masked_low = mask(masked_low, blur_zip, 'zip', nFields)
masked_low = mask(masked_low, generalize_diagnosis, 'diagnosis', level)
masked_low = mask(masked_low, add_relative_noise, 'height', relNoise)
masked_low = mask(masked_low, blur_phone, 'phone', nFields_phone)

# %%
masked_low.to_csv(dir + "/datasets/masked/masked_low.csv")

# %%
b_size = 10
nFields = 3
level = 2
relNoise = 0.10
nFields_phone = 5

masked_medium = mask(df_synthetic_data, bucketize_age, 'age', b_size)
masked_medium = mask(masked_medium, blur_zip, 'zip', nFields)
masked_medium = mask(masked_medium, generalize_diagnosis, 'diagnosis', level)
masked_medium = mask(masked_medium, add_relative_noise, 'height', relNoise)
masked_medium = mask(masked_medium, blur_phone, 'phone', nFields_phone)

# %%
masked_medium.to_csv(dir + "/datasets/masked/masked_medium.csv")

# %%
b_size = 20
nFields = 4
level = 2
relNoise = 0.20
nFields_phone = 7

masked_high = mask(df_synthetic_data, bucketize_age, 'age', b_size)
masked_high = mask(masked_high, blur_zip, 'zip', nFields)
masked_high = mask(masked_high, generalize_diagnosis, 'diagnosis', level)
masked_high = mask(masked_high, add_relative_noise, 'height', relNoise)
masked_high = mask(masked_high, blur_phone, 'phone', nFields_phone)

# %%
masked_high.to_csv(dir + "/datasets/masked/masked_high.csv")

# %%
masked_high
# Out:
#     id                               name  gender            age  height  \
# 0    1            Dr. Magrit Bonbach MBA.  Female  [40.0 - 59.0]     191
# 1    2               Hanspeter Beyer B.A.    Male  [80.0 - 99.0]     167
# 2    3              Anatolij Roskoth B.A.    Male  [20.0 - 39.0]     146
# 3    4       Dipl.-Ing. Teresa Karz B.Sc.  Female  [60.0 - 79.0]     188
# 4    5                     Björn Misicher    Male  [60.0 - 79.0]     215
# 5    6               Herrmann Tröst B.Sc.    Male  [60.0 - 79.0]     158
# 6    7                 Henner Putz B.Eng.    Male  [40.0 - 59.0]     158
# 7    8                Traude Hövel-Aumann  Female  [20.0 - 39.0]     173
# 8    9                   Gertraud Langern  Female  [40.0 - 59.0]     148
# 9   10   Univ.Prof. Liselotte Hecker B.A.  Female  [40.0 - 59.0]     200
# 10  11                          Gert Mude    Male  [60.0 - 79.0]     152
# 11  12            Ing. Hülya Rogge B.Eng.  Female  [40.0 - 59.0]     172
# 12  13                        Lotte Zirme  Female  [20.0 - 39.0]     148
# 13  14                       Zoran Söding    Male  [20.0 - 39.0]     197
# 14  15                    Henri Holzapfel  Female  [60.0 - 79.0]     142
# 15  16       Univ.Prof. Kemal Eberth MBA.    Male  [40.0 - 59.0]     167
# 16  17                    Berthold Eberth    Male  [40.0 - 59.0]     171
# 17  18                  Elly Blümel-Ebert  Female  [60.0 - 79.0]     196
# 18  19         Prof. Olivia Wilmsen B.Sc.  Female  [60.0 - 79.0]     173
# 19  20     Dipl.-Ing. Ingetraud Hertrampf  Female  [80.0 - 99.0]     140
# 20  21                        Paula Wilms  Female  [20.0 - 39.0]     195
# 21  22                    Laszlo Eckbauer    Male  [60.0 - 79.0]     218
# 22  23                Canan Fischer B.Sc.  Female  [40.0 - 59.0]     169
# 23  24                Marco Hecker B.Eng.    Male  [40.0 - 59.0]     199
# 24  25                    Gerwin Lachmann    Male  [60.0 - 79.0]     167
# 25  26  Dipl.-Ing. Stefano Ullmann B.Eng.    Male  [60.0 - 79.0]     207
# 26  27                     Birgit Seifert  Female  [40.0 - 59.0]     173
# 27  28               Miguel Bonbach-Preiß    Male  [60.0 - 79.0]     171
# 28  29                 Fatih Döring B.Sc.    Male  [20.0 - 39.0]     165
# 29  30                 Filippo Löwer-Seip    Male  [60.0 - 79.0]     207
# 30  31                         Alf Adolph    Male  [80.0 - 99.0]     167
# 31  32                   Siegmund Matthäi    Male  [40.0 - 59.0]     153
# 32  33                  Dietlind Losekann  Female  [60.0 - 79.0]     188
# 33  34                Maria-Luise Hartung  Female  [40.0 - 59.0]     145
# 34  35           Frau Martha Fritsch B.A.  Female  [40.0 - 59.0]     191
# 35  36                         Nuri Krein    Male  [60.0 - 79.0]     203
# 36  37                 August Hethur B.A.    Male  [40.0 - 59.0]     195
# 37  38                     Carsten Weller    Male  [80.0 - 99.0]     137
# 38  39                     Jose Kostolzin    Male  [60.0 - 79.0]     159
# 39  40                   Dr. Simona Beyer  Female   [0.0 - 19.0]     197
# 40  41                      Anneke Jopich  Female  [20.0 - 39.0]     147
# 41  42                      Lore Oderwald  Female  [60.0 - 79.0]     143
# 42  43                  Ingmar Dussen van    Male  [20.0 - 39.0]     167
# 43  44                     Alwin Rörricht    Male   [0.0 - 19.0]     212
# 44  45                       Cilli Renner  Female  [40.0 - 59.0]     161
# 45  46   Prof. Philipp Austermühle B.Eng.    Male  [80.0 - 99.0]     175
# 46  47                     Georg Gröttner    Male  [40.0 - 59.0]     172
# 47  48                  Karolina Herrmann  Female  [40.0 - 59.0]     192
# 48  49                  Andrei Dussen van    Male  [60.0 - 79.0]     161
# 49  50                Ing. Hasso Herrmann    Male  [60.0 - 79.0]     209
#
#     weight diagnosis                       address    zip                phone
# 0       53     PXX.X            Olaf-Zobel-Allee 9  2XXXX          0041XXXXXXX
# 1       84     ZXX.X               Schomberplatz 7  1XXXX          0730XXXXXXX
# 2       91     LXX.X                  Römerplatz 1  2XXXX  +49 (0) 3924XXXXXXX
# 3       57     VXX.X                 Stiffelstr. 9  6XXXX         02894XXXXXXX
# 4       79     NXX.X             Paffrathallee 9/5  7XXXX        (01843XXXXXXX
# 5       70     GXX.X                 Mendegasse 84  5XXXX     +49(0)420XXXXXXX
# 6       83     RXX.X           Neuschäferstraße 20  1XXXX  +49 (0) 0058XXXXXXX
# 7       54     KXX.X         Jolanda-Wilms-Allee 9  4XXXX         04948XXXXXXX
# 8       63     VXX.X                Schülerallee 0  4XXXX     +49(0)938XXXXXXX
# 9       68     VXX.X        Gerta-Krause-Gasse 843  2XXXX     +49(0) 44XXXXXXX
# 10      78     LXX.X           Dussen vanallee 5/4  8XXXX     +49(0) 35XXXXXXX
# 11      66     PXX.X             Wilmsenstraße 9/1  9XXXX           043XXXXXXX
# 12      64     CXX.X                  Netteallee 1  2XXXX        (03614XXXXXXX
# 13      75     JXX.X  Ernestine-Förster-Straße 6/4  6XXXX     +49(0)120XXXXXXX
# 14      54     LXX.X                Wulffallee 192  5XXXX     +49(0)058XXXXXXX
# 15      82     KXX.X                Geißlerallee 5  3XXXX          0650XXXXXXX
# 16      94     ZXX.X     Edelgard-Wähner-Straße 82  3XXXX          0057XXXXXXX
# 17      60     GXX.X        Veronica-Etzler-Weg 99  3XXXX          0145XXXXXXX
# 18      72     TXX.X       Christin-Köster-Gasse 1  5XXXX          0042XXXXXXX
# 19      62     JXX.X                Wendegasse 027  9XXXX       (09684)XXXXXXX
# 20      60     NXX.X     Helfried-Aumann-Allee 9/9  5XXXX    +49(0)6415XXXXXXX
# 21      62     OXX.X             Säuberlichweg 608  1XXXX       (00726)XXXXXXX
# 22      62     QXX.X   Hanne-Lore-Flantz-Platz 916  4XXXX        (07984XXXXXXX
# 23     103     AXX.X      Sofie-Birnbaum-Straße 08  6XXXX         03561XXXXXXX
# 24      71     BXX.X                 Walterallee 1  6XXXX    +49(0)4796XXXXXXX
# 25      74     KXX.X         Anka-Drewes-Allee 916  0XXXX     +49(0)893XXXXXXX
# 26      55     MXX.X                 Gunpfring 0/6  3XXXX        (06125XXXXXXX
# 27     105     JXX.X    Ellinor-Cichorius-Platz 81  2XXXX           067XXXXXXX
# 28      78     VXX.X                Preißallee 5/5  6XXXX          0013XXXXXXX
# 29      75     IXX.X   Liselotte-Kitzmann-Gasse 65  8XXXX          0612XXXXXXX
# 30     100     OXX.X               Rosenowallee 94  0XXXX         03761XXXXXXX
# 31      70     TXX.X       Magrit-Junck-Straße 275  8XXXX  +49 (0) 3769XXXXXXX
# 32      65     FXX.X                 Roggestr. 822  4XXXX  +49 (0) 9252XXXXXXX
# 33      55     MXX.X                   Kochweg 0/5  7XXXX        (00269XXXXXXX
# 34      44     TXX.X       Oxana-Hermann-Allee 769  2XXXX    +49(0)8564XXXXXXX
# 35      93     GXX.X     Willibald-Mälzer-Ring 7/0  2XXXX          0580XXXXXXX
# 36      87     GXX.X                 Wilmsstr. 2/9  0XXXX     +49(0) 56XXXXXXX
# 37      83     PXX.X             Gutknechtgasse 04  9XXXX         08164XXXXXXX
# 38      85     QXX.X             Hentschelplatz 84  0XXXX          0315XXXXXXX
# 39      57     OXX.X            Scheuermannplatz 5  8XXXX       (05594)XXXXXXX
# 40      72     TXX.X               Hertrampfring 7  9XXXX     +49(0)195XXXXXXX
# 41      55     SXX.X            Lili-Stoll-Ring 20  1XXXX           022XXXXXXX
# 42      66     FXX.X       Susann-Hermann-Straße 4  7XXXX           004XXXXXXX
# 43      96     LXX.X          Cemil-Täsche-Gasse 3  6XXXX           050XXXXXXX
# 44      60     FXX.X      Andrea-Margraf-Gasse 1/2  9XXXX           059XXXXXXX
# 45      81     YXX.X                Binnerring 906  8XXXX    +49(0)6683XXXXXXX
# 46      87     NXX.X       Laila-Scholz-Straße 9/4  0XXXX         03877XXXXXXX
# 47      49     JXX.X               Kranzstraße 475  2XXXX     +49(0)433XXXXXXX
# 48      98     QXX.X       Manuela-Bloch-Platz 3/5  0XXXX          0775XXXXXXX
# 49      72     SXX.X               Hübelstraße 898  7XXXX  +49 (0) 4386XXXXXXX

# %%
df['zip']
# Out:
# 0     24455
# 1     16661
# 2     23765
# 3     60825
# 4     78781
# 5     53313
# 6     16128
# 7     44109
# 8     47725
# 9     26285
# 10    84413
# 11    99364
# 12    21885
# 13    61019
# 14    50037
# 15    39327
# 16    38001
# 17    39626
# 18    53465
# 19    95348
# 20    57178
# 21    13615
# 22    49513
# 23    62506
# 24    68521
# 25    01897
# 26    39478
# 27    25116
# 28    66383
# 29    81076
# 30    03280
# 31    83084
# 32    42513
# 33    70517
# 34    22558
# 35    23293
# 36    06187
# 37    97154
# 38    01856
# 39    84565
# 40    91153
# 41    14542
# 42    71417
# 43    69164
# 44    96801
# 45    81922
# 46    01468
# 47    23497
# 48    03000
# 49    78621
# Name: zip, dtype: object

# %%
a = 2
b = 3
(a,b)
# Out:
# (2, 3)
